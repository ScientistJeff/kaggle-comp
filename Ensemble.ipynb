# %%
import sys

import os
import numpy as np
import pandas as pd

# %%
RF = pd.read_csv('./sample_sub_RF_4-6.csv')
XGBPP = pd.read_csv('./sample_sub_XGB_4-6_2.csv')
XGBOL = pd.read_csv('./submission-XGB-OL-4-10.csv')

# %%
ensemble = RF.copy()

ensemble['TARGET'] = XGBOL['TARGET']*0.75+XGBPP['TARGET']*0.15+RF['TARGET']*0.1

ensemble.to_csv('sub_ensemble_4-14.csv',index=False)

# %%
ensemble
# Out:
#            ID    TARGET
# 0           2  0.080513
# 1           5  0.060563
# 2           6  0.001604
# 3           7  0.013955
# 4           9  0.003583
# 5          11  0.233884
# 6          12  0.028616
# 7          15  0.161232
# 8          16  0.055297
# 9          17  0.021293
# 10         19  0.028494
# 11         21  0.008683
# 12         22  0.017179
# 13         24  0.012247
# 14         27  0.014942
# 15         28  0.018874
# 16         30  0.144397
# 17         33  0.003436
# 18         35  0.014490
# 19         37  0.019029
# 20         38  0.033048
# 21         40  0.181485
# 22         41  0.028789
# 23         44  0.012602
# 24         46  0.085907
# 25         47  0.018917
# 26         48  0.009625
# 27         50  0.011705
# 28         52  0.164862
# 29         53  0.011419
# ...       ...       ...
# 75788  151772  0.005486
# 75789  151773  0.032328
# 75790  151776  0.015348
# 75791  151777  0.055989
# 75792  151780  0.009926
# 75793  151781  0.018147
# ...
